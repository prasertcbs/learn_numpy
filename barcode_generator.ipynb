# %%
import barcode # pip install python-barcode
from IPython.display import SVG, display

# %%
barcode.PROVIDED_BARCODES

# %% [markdown]
# ## method 1

# %%
EAN = barcode.get_barcode_class('ean13')

# %%
ean = EAN('8858833504101')

# %%
ean
# Out:
# <EuropeanArticleNumber13('8858833504101')>

# %%
fullname = ean.save('ean13_barcode') # svg format

# %%
fullname
# Out:
# 'ean13_barcode.svg'

# %%
display(SVG(fullname))

# %% [markdown]
# ## method 2

# %%
# pip install python-barcode
from barcode import generate

# %%
svg_img=generate('EAN13', '5901234123457', 
             output='barcode1')

# %%
display(SVG('barcode1.svg'))
