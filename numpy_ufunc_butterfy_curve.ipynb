# %% [markdown]
# # NumPy ufunc (universal functions)

# %%
import numpy as np
print(f'NumPy version = {np.__version__}')
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# NumPy version = 1.14.5

# %% [markdown]
# ## unary ufunc

# %%
np.sqrt(2)
# Out:
# 1.4142135623730951

# %%
np.abs(-5)
# Out:
# 5

# %%
a=np.arange(1, 11)
root=np.sqrt(a)
root
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        , 2.23606798,
#        2.44948974, 2.64575131, 2.82842712, 3.        , 3.16227766])

# %%
np.log(a) # natural log
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436, 1.60943791,
#        1.79175947, 1.94591015, 2.07944154, 2.19722458, 2.30258509])

# %%
np.log10(a)
# Out:
# array([0.        , 0.30103   , 0.47712125, 0.60205999, 0.69897   ,
#        0.77815125, 0.84509804, 0.90308999, 0.95424251, 1.        ])

# %% [markdown]
# ### butterfly curve
# https://en.wikipedia.org/wiki/Butterfly_curve_(transcendental)

# %% [markdown]
# $$
# x=\sin(t)\left(e^{\cos(t)}-2\cos(4t)-\sin ^{5}\left({t \over 12}\right)\right) \\
# y=\cos(t)\left(e^{\cos(t)}-2\cos(4t)-\sin ^{5}\left({t \over 12}\right)\right) \\
# {0\leq t\leq 12\pi }
# $$

# %%
t=np.linspace(0, 12*np.pi, 360*5)

# %%
t
# Out:
# array([0.00000000e+00, 2.09555930e-02, 4.19111860e-02, ...,
#        3.76572007e+01, 3.76781563e+01, 3.76991118e+01])

# %%
x=np.sin(t)*(np.exp(np.cos(t))-2*np.cos(4*t)-np.sin(t/12)**5)

# %%
y=np.cos(t)*(np.exp(np.cos(t))-2*np.cos(4*t)-np.sin(t/12)**5)

# %%
plt.plot(x,y)

# %% [markdown]
# ## binary ufunc

# %%
a=np.random.randint(1, 10, (4, 2))
a
# Out:
# array([[9, 1],
#        [3, 5],
#        [6, 2],
#        [4, 9]])

# %%
b=np.random.randint(1, 10, (4, 2))
b
# Out:
# array([[4, 8],
#        [4, 1],
#        [8, 5],
#        [5, 6]])

# %%
np.maximum(a, b)
# Out:
# array([[9, 8],
#        [4, 5],
#        [8, 5],
#        [5, 9]])

# %%
np.add(a, b)
# Out:
# array([[13,  9],
#        [ 7,  6],
#        [14,  7],
#        [ 9, 15]])

# %%
a + b
# Out:
# array([[13,  9],
#        [ 7,  6],
#        [14,  7],
#        [ 9, 15]])
