# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
print(f'NumPy version = {np.__version__}')
# Out:
# NumPy version = 1.14.5

# %%
# conda install pillow
from PIL import Image, ImageDraw, ImageFont # pillow package (Python Image Library)
import io

# %%
img = Image.open('tiger.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=203x141 at 0x115FFB710>

# %%
img.size # (width, height)
# Out:
# (203, 141)

# %%
a=np.uint8(img)
a.shape
# Out:
# (141, 203, 4)

# %%
Image.fromarray(a)
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x11610EE80>

# %%
Image.fromarray(a[::-1])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x11608B630>

# %%
Image.fromarray(a[:, ::-1, :])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x116104BE0>

# %%
Image.fromarray(a[::-1, ::-1, :])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x116104588>

# %%
Image.fromarray(a[:, ::-1, :])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x116123240>

# %%
Image.fromarray(a[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x116104160>

# %%
a.shape
# Out:
# (141, 203, 4)

# %%
a.strides
# Out:
# (812, 4, 1)

# %%
b=a.transpose(1, 0, 2).strides
b[:5]
# Out:
# (4, 812, 1)

# %%
Image.fromarray(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-c52daefb8e3e> in <module>()
# ----> 1 Image.fromarray(b)
#
# ~/miniconda3/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2419     .. versionadded:: 1.1.6
#    2420     """
# -> 2421     arr = obj.__array_interface__
#    2422     shape = arr['shape']
#    2423     ndim = len(shape)
#
# AttributeError: 'tuple' object has no attribute '__array_interface__'

# %%
# a[100] = 0

# %%
a.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : False
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
a.setflags(write=1)

# %%
a[100:111] = [255, 0, 0, 255]

# %%
Image.fromarray(a)
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7FC598F1B668>

# %%
Image.fromarray(a[::-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2427             typekey = (1, 1) + shape[2:], arr['typestr']
# -> 2428             mode, rawmode = _fromarray_typemap[typekey]
#    2429         except KeyError:
#
# KeyError: ((1, 1, 4), '<f8')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-5ff227e96f5e> in <module>()
# ----> 1 Image.fromarray(a[::-1])
#
# ~/miniconda3/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2429         except KeyError:
#    2430             # print(typekey)
# -> 2431             raise TypeError("Cannot handle this data type")
#    2432     else:
#    2433         rawmode = mode
#
# TypeError: Cannot handle this data type

# %%
img2 = Image.fromarray(a)
img2
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7FC598F1BAC8>

# %%
a.shape
# Out:
# (141, 203, 4)

# %%
Image.fromarray(np.uint8(a[::-1]))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7FC598F1BC88>

# %%
Image.fromarray(np.uint8(a[::-1]))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7FC598F1BD68>

# %%
Image.fromarray(np.uint8(a * .5))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7FC598F2F080>

# %%
a[a > 0]
# Out:
# array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)

# %%
a = a * .5

# %%
Image.fromarray(np.uint8(a))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7FC598F2F358>

# %%
a.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
a.setflags(write=1)

# %%
a[::2] = 128

# %%
Image.fromarray(np.uint8(a[::2]))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x71 at 0x7FC598F2F710>

# %%
a
# Out:
# array([[[128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         ...,
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ]],
#
#        [[127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         ...,
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5]],
#
#        [[128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         ...,
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ]],
#
#        ...,
#
#        [[128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         ...,
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ]],
#
#        [[127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         ...,
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5]],
#
#        [[128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         ...,
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ]]])

# %%
a[::2]
# Out:
# array([[[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        ...,
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]]])

# %%
a[:, :, 0]
# Out:
# array([[128. , 128. , 128. , ..., 128. , 128. , 128. ],
#        [127.5, 127.5, 127.5, ..., 127.5, 127.5, 127.5],
#        [128. , 128. , 128. , ..., 128. , 128. , 128. ],
#        ...,
#        [128. , 128. , 128. , ..., 128. , 128. , 128. ],
#        [127.5, 127.5, 127.5, ..., 127.5, 127.5, 127.5],
#        [128. , 128. , 128. , ..., 128. , 128. , 128. ]])

# %%
a[a[:, :, 0] > 0]
# Out:
# array([[128., 128., 128., 128.],
#        [128., 128., 128., 128.],
#        [128., 128., 128., 128.],
#        ...,
#        [128., 128., 128., 128.],
#        [128., 128., 128., 128.],
#        [128., 128., 128., 128.]])
